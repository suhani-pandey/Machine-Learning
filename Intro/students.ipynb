# %%
import sympy as sp
from scipy import *
from sympy import *
init_printing()
from IPython.display import display, Latex, HTML, Math
import numpy as np
import pandas as pd
from sympy import Rational as R
import math as math
from math import inf
import pandas as pd

# %% [markdown]
# # Reading Data

# %%
students = pd.read_csv('students.csv')
students
# Out:
#                   name               nationality                 city  \
# 0            Kiana Lor                     China               Suzhou
# 1       Joshua Lonaker  United States of America        Santa Clarita
# 2        Dakota Blanco  United States of America              Oakland
# 3      Natasha Yarusso  United States of America        Castro Valley
# 4       Brooke Cazares                    Brazil  São José dos Campos
# ..                 ...                       ...                  ...
# 302        Austin Haas  United States of America             Columbus
# 303    Madison Fithian  United States of America          Los Angeles
# 304  Zachary Mulvahill  United States of America          Los Angeles
# 305   Eliana Michelsen  United States of America              Oakland
# 306    Dane Whittemore                    Canada              Toronto
#
#      latitude  longitude gender  age  english.grade  math.grade  \
# ...

# %% [markdown]
# # Display single/multiple columns

# %%
# display a single column
students['name']
# display two columns
students[['name', 'city']]
# Out:
#                   name                 city
# 0            Kiana Lor               Suzhou
# 1       Joshua Lonaker        Santa Clarita
# 2        Dakota Blanco              Oakland
# 3      Natasha Yarusso        Castro Valley
# 4       Brooke Cazares  São José dos Campos
# ..                 ...                  ...
# 302        Austin Haas             Columbus
# 303    Madison Fithian          Los Angeles
# 304  Zachary Mulvahill          Los Angeles
# 305   Eliana Michelsen              Oakland
# 306    Dane Whittemore              Toronto
#
# [307 rows x 2 columns]

# %% [markdown]
# # other way to display a single column

# %%
students.name
# Out:
# 0              Kiana Lor
# 1         Joshua Lonaker
# 2          Dakota Blanco
# 3        Natasha Yarusso
# 4         Brooke Cazares
#              ...
# 302          Austin Haas
# 303      Madison Fithian
# 304    Zachary Mulvahill
# 305     Eliana Michelsen
# 306      Dane Whittemore
# Name: name, Length: 307, dtype: object

# %% [markdown]
# # Display first n rows

# %%
students.head(3)
# Out:
#              name               nationality           city  latitude  \
# 0       Kiana Lor                     China         Suzhou     31.31
# 1  Joshua Lonaker  United States of America  Santa Clarita     34.39
# 2   Dakota Blanco  United States of America        Oakland     37.80
#
#    longitude gender  age  english.grade  math.grade  sciences.grade  \
# 0     120.62      F   22            3.5         3.7             3.1
# 1    -118.54      M   22            2.9         3.2             3.6
# 2    -122.27      F   22            3.9         3.8             3.2
#
#    language.grade  portfolio.rating  coverletter.rating  refletter.rating
# 0             1.0                 4                 4.0                 4
# 1             5.0                 5                 4.0                 5
# 2             5.0                 3                 3.0                 4

# %% [markdown]
# # Display last n rows

# %%
students.tail(3)
# Out:
#                   name               nationality         city  latitude  \
# 304  Zachary Mulvahill  United States of America  Los Angeles     34.05
# 305   Eliana Michelsen  United States of America      Oakland     37.80
# 306    Dane Whittemore                    Canada      Toronto     43.67
#
#      longitude gender  age  english.grade  math.grade  sciences.grade  \
# 304    -118.24      M   20            3.2         3.4             3.9
# 305    -122.27      F   23            3.0         2.8             2.9
# 306     -79.42      M   21            3.8         3.2             4.0
#
#      language.grade  portfolio.rating  coverletter.rating  refletter.rating
# 304             5.0                 5                 5.0                 3
# 305             5.0                 4                 4.0                 5
# 306             5.0                 5                 4.0                 5

# %% [markdown]
# # Display row by index

# %%
students.iloc[2]
# difference between iloc and loc
# iloc - integer location
# loc - label based location
# Out:
# name                             Dakota Blanco
# nationality           United States of America
# city                                   Oakland
# latitude                                  37.8
# longitude                              -122.27
# gender                                       F
# age                                         22
# english.grade                              3.9
# math.grade                                 3.8
# sciences.grade                             3.2
# language.grade                             5.0
# portfolio.rating                             3
# coverletter.rating                         3.0
# refletter.rating                             4
# Name: 2, dtype: object

# %% [markdown]
# # Row slicing; Display row by index range

# %%
students[2:5] # display rows from 2 to 4
# Out:
#               name               nationality                 city  latitude  \
# 2    Dakota Blanco  United States of America              Oakland     37.80
# 3  Natasha Yarusso  United States of America        Castro Valley     37.69
# 4   Brooke Cazares                    Brazil  São José dos Campos    -23.18
#
#    longitude gender  age  english.grade  math.grade  sciences.grade  \
# 2    -122.27      F   22            3.9         3.8             3.2
# 3    -122.09      F   20            3.3         2.8             3.2
# 4     -45.88      F   21            3.7         2.6             3.4
#
#    language.grade  portfolio.rating  coverletter.rating  refletter.rating
# 2             5.0                 3                 3.0                 4
# 3             5.0                 5                 2.0                 4
# 4             1.0                 4                 4.0                 5

# %% [markdown]
# # Display every nth row

# %%
students[::2] # display every 2nd row
# Out:
#                   name               nationality                 city  \
# 0            Kiana Lor                     China               Suzhou
# 2        Dakota Blanco  United States of America              Oakland
# 4       Brooke Cazares                    Brazil  São José dos Campos
# 6           Joey Abreu                     China             Shenyang
# 8             Lee Dong               Philippines               Manila
# ..                 ...                       ...                  ...
# 298       Nicolas Papp  United States of America             New York
# 300    Tessa Rawanduzy  United States of America                Derby
# 302        Austin Haas  United States of America             Columbus
# 304  Zachary Mulvahill  United States of America          Los Angeles
# 306    Dane Whittemore                    Canada              Toronto
#
#      latitude  longitude gender  age  english.grade  math.grade  \
# ...

# %% [markdown]
# # Display row by index and column

# %%
students.iloc[2, 1]
# Out:
# 'United States of America'

# %% [markdown]
# # Extract Sub data frame

# %%
students.iloc[::3][['name', 'city']]
students.iloc[::3, [1, 3]]
# Out:
#                   nationality  latitude
# 0                       China     31.31
# 3    United States of America     37.69
# 6                       China     41.79
# 9                      Turkey     41.02
# 12   United States of America     41.26
# ..                        ...       ...
# 294  United States of America     32.72
# 297  United States of America     35.23
# 300  United States of America     37.55
# 303  United States of America     34.05
# 306                    Canada     43.67
#
# [103 rows x 2 columns]

# %% [markdown]
# # check unique entries

# %%
students['city'].unique()
# other way
students.city.unique()
# Out:
# array(['Suzhou', 'Santa Clarita', 'Oakland', 'Castro Valley',
#        'São José dos Campos', 'Indianapolis', 'Shenyang', 'São Paulo',
#        'Manila', 'Istanbul', 'Dallas', 'Chicago', 'Omaha', 'Tijuana',
#        'Mission Viejo', 'Tokyo', 'Los Angeles', 'Mexico', 'Toronto',
#        'Moreno Valley', 'Peking', 'Rawalpindi', 'Hebi', 'Santa Barbara',
#        'Manteca', 'South Hill', 'Modesto', 'Santo Domingo', 'Sacramento',
#        'Phoenix', 'Detroit', 'Kanpur', 'Lima', 'New York', 'New Delhi',
#        'Moscow', 'Fremont', 'Lafayette', 'West Jordan', 'Mexicali',
#        'Tehuacán', 'Madrid', 'Walnut Creek', 'Memphis', 'Charlotte',
#        'San Diego', 'Khalabat', 'Shanghai', 'San Jose', 'Warsaw',
#        'Stockton', 'Seoul', 'Portland', 'Manzanillo', 'Bombay',
#        'Roseville', 'Wuhan', 'Manzil Tamim', 'Kettering', 'Rangoon',
#        'Waukegan', 'Visalia', 'Boulder', 'Nizhniy Novgorod', 'Pereira',
#        'Foz do Iguaçu', 'Kashiwara', 'Kawasaki', 'Karachi',
# ...

# %%
students[students.nationality == 'Mexico']
# or mulitple operation 
students[(students.nationality == 'Mexico') & (students.age > 22)]
# Out:
#                          name nationality        city  latitude  longitude  \
# 13              Edgar Sanchez      Mexico     Tijuana     32.53    -117.02
# 17             Ericka Arreola      Mexico      Mexico     19.43     -99.14
# 50                 Issac Mata      Mexico    Tehuacán     18.45     -97.38
# 82                 Staci Maes      Mexico      Mexico     19.43     -99.14
# 112  Christian Zambrano-Munoz      Mexico    Mexicali     32.65    -115.47
# 178           Latino Calderon      Mexico  Hermosillo     29.07    -110.97
# 191          Jonathan Nevarez      Mexico      Mexico     19.43     -99.14
# 210              Carlos Anaya      Mexico      Mexico     19.43     -99.14
# 236                Max Flores      Mexico     Tijuana     32.53    -117.02
# 296        Brittany Fernandez      Mexico      Zamora     19.98    -102.27
#
#     gender  age  english.grade  math.grade  sciences.grade  language.grade  \
# ...

# %% [markdown]
# # Creating data frame from data

# %%
pd.DataFrame([10, 11, 12, 13]) # one dimensional data
# Out:
#     0
# 0  10
# 1  11
# 2  12
# 3  13

# %%
# data frame using dictionary
pd.DataFrame({'A': [1, 2, 3], 'B': ['one', 'two', 'three']})
# Out:
#    A      B
# 0  1    one
# 1  2    two
# 2  3  three

# %%
pd.DataFrame([[10, 11], [12, 13]])  # two dimensional list
# Out:
#     0   1
# 0  10  11
# 1  12  13
